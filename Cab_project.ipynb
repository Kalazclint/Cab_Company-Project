# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-darkgrid")

# %%
cab_data = "C:/Users/CLINTON/Documents/My documents/LLM/Informatics/Data Glacier/github data/Cab_Data.csv"
cab_data = pd.read_csv(cab_data)

# %%
cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     08-01-2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     06-01-2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     02-01-2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     07-01-2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     03-01-2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_data['Profit'] = cab_data['Price Charged'] - cab_data['Cost of Trip']

# %%
cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     08-01-2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     06-01-2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     02-01-2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     07-01-2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     03-01-2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit
# 0         370.95       313.635  57.315
# 1         358.52       334.854  23.666
# 2         125.20        97.632  27.568
# 3         377.40       351.602  25.798
# 4         114.62        97.776  16.844

# %%
profit_by_City = cab_data.groupby(['Company','City'])['Profit'].sum().reset_index().sort_values(by='Profit', ascending = False)
profit_by_City
# Out:
#        Company            City        Profit
# 28  Yellow Cab     NEW YORK NY  2.645108e+07
# 37  Yellow Cab   WASHINGTON DC  3.299104e+06
# 25  Yellow Cab  LOS ANGELES CA  3.285977e+06
# 22  Yellow Cab      CHICAGO IL  3.068591e+06
# 9     Pink Cab     NEW YORK NY  1.511474e+06
# 21  Yellow Cab       BOSTON MA  1.506718e+06
# 6     Pink Cab  LOS ANGELES CA  1.125732e+06
# 23  Yellow Cab       DALLAS TX  1.104003e+06
# 35  Yellow Cab  SILICON VALLEY  9.764547e+05
# 33  Yellow Cab    SAN DIEGO CA  9.492737e+05
# 19  Yellow Cab      ATLANTA GA  7.463828e+05
# 14    Pink Cab    SAN DIEGO CA  6.378898e+05
# 26  Yellow Cab        MIAMI FL  5.960001e+05
# 34  Yellow Cab      SEATTLE WA  4.919035e+05
# 20  Yellow Cab       AUSTIN TX  3.792557e+05
# 24  Yellow Cab       DENVER CO  3.570001e+05
# 29  Yellow Cab   ORANGE COUNTY  3.550060e+05
# 16    Pink Cab  SILICON VALLEY  3.402505e+05
# 3     Pink Cab      CHICAGO IL  3.187225e+05
# 2     Pink Cab       BOSTON MA  2.620017e+05
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter(profit_by_City, x="City", y="Profit", size="Profit", hover_name="City", title='Profit by City', color = 'Company', size_max=60)
fig.show()
# Out:
# <div>                            <div id="6dc40f3e-ca6e-4943-9002-4ad3ffa711f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dc40f3e-ca6e-4943-9002-4ad3ffa711f2")) {                    Plotly.newPlot(                        "6dc40f3e-ca6e-4943-9002-4ad3ffa711f2",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Company=Yellow Cab<br>City=%{x}<br>Profit=%{marker.size}<extra></extra>","hovertext":["NEW YORK NY","WASHINGTON DC","LOS ANGELES CA","CHICAGO IL","BOSTON MA","DALLAS TX","SILICON VALLEY","SAN DIEGO CA","ATLANTA GA","MIAMI FL","SEATTLE WA","AUSTIN TX","DENVER CO","ORANGE COUNTY","PHOENIX AZ","NASHVILLE TN","TUCSON AZ","PITTSBURGH PA","SACRAMENTO CA"],"legendgroup":"Yellow Cab","marker":{"color":"#636efa","size":[2645108
# ...

# %% [markdown]
# The bubble plot shows that for each state, the total profits is higher for the yellow cab than the Pink Cab, with the maximum profit coming from the Yellow cab in New York. The Pink cab also has its maximum profit in New York

# %%
cab_data.shape
# Out:
# (359392, 8)

# %%
cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# Profit            0
# dtype: int64

# %%
cities = 'C:/Users/CLINTON/Documents/My documents/LLM/Informatics/Data Glacier/Cities.csv'
cities = pd.read_csv(cities)
cities
# Out:
#                 City Population    Users
# 0        NEW YORK NY  8,405,837  302,149
# 1         CHICAGO IL  1,955,130  164,468
# 2     LOS ANGELES CA  1,595,037  144,132
# 3           MIAMI FL  1,339,155   17,675
# 4     SILICON VALLEY  1,177,609   27,247
# 5      ORANGE COUNTY  1,030,185   12,994
# 6       SAN DIEGO CA    959,307   69,995
# 7         PHOENIX AZ    943,999    6,133
# 8          DALLAS TX    942,908   22,157
# 9         ATLANTA GA    814,885   24,701
# 10         DENVER CO    754,233   12,421
# 11         AUSTIN TX    698,371   14,978
# 12        SEATTLE WA    671,238   25,063
# 13         TUCSON AZ    631,442    5,712
# 14  SAN FRANCISCO CA    629,591  213,609
# 15     SACRAMENTO CA    545,776    7,044
# 16     PITTSBURGH PA    542,085    3,643
# 17     WASHINGTON DC    418,859  127,001
# 18      NASHVILLE TN    327,225    9,270
# 19         BOSTON MA    248,968   80,021

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
cities['Users'] = cities['Users'].replace({',':''}, regex = True)
cities['Users'].astype(str).astype(float)
# Out:
# 0     302149.0
# 1     164468.0
# 2     144132.0
# 3      17675.0
# 4      27247.0
# 5      12994.0
# 6      69995.0
# 7       6133.0
# 8      22157.0
# 9      24701.0
# 10     12421.0
# 11     14978.0
# 12     25063.0
# 13      5712.0
# 14    213609.0
# 15      7044.0
# 16      3643.0
# 17    127001.0
# 18      9270.0
# 19     80021.0
# Name: Users, dtype: float64

# %%
cities.head()
# Out:
#              City Population   Users
# 0     NEW YORK NY  8,405,837  302149
# 1      CHICAGO IL  1,955,130  164468
# 2  LOS ANGELES CA  1,595,037  144132
# 3        MIAMI FL  1,339,155   17675
# 4  SILICON VALLEY  1,177,609   27247

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
customer_id = "C:/Users/CLINTON/Documents/My documents/LLM/Informatics/Data Glacier/Customer_ID.csv"
customer_id = pd.read_csv(customer_id)
customer_id
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_id.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
transaction_id = "C:/Users/CLINTON/Documents/My documents/LLM/Informatics/Data Glacier/Transaction_ID.csv"
transaction_id = pd.read_csv(transaction_id)
transaction_id
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transaction_id.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
data = pd.merge(left=customer_id, right=transaction_id, on='Customer ID', how='inner')
data.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card

# %%
data
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...

# %%
#Joining with data with cab_data by transaction ID
data = pd.merge(left= cab_data, right= data, on='Transaction ID', how='inner')
data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     08-01-2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     06-01-2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     02-01-2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     07-01-2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     03-01-2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit  Customer ID Gender  Age  \
# 0         370.95       313.635  57.315        29290   Male   28
# 1         358.52       334.854  23.666        27703   Male   27
# 2         125.20        97.632  27.568        28712   Male   53
# 3         377.40       351.602  25.798        28020   Male   23
# 4         114.62        97.776  16.844        27182   Male   33
#
#    Income (USD/Month) Payment_Mode
# 0               10813         Card
# 1                9237         Card
# 2               11242         Cash
# ...

# %%
data['Date of Travel'].max()
# Out:
# '31-12-2018'

# %%
data['Date of Travel'].min()
# Out:
# '01-01-2017'

# %%
outputfile = 'C:/Users/CLINTON/Documents/My documents/LLM/Informatics/Data Glacier/data_cab.csv'
data.to_csv(outputfile, index=False)

# %%
#Checking Cab with most transactions during the time period
tran_by_comp = data.groupby('Company')['Transaction ID'].count().reset_index().sort_values(by='Transaction ID', ascending = False)
tran_by_comp.rename(columns={'Transaction ID': 'demand'}, inplace=True)
tran_by_comp
# Out:
#       Company  demand
# 1  Yellow Cab  274681
# 0    Pink Cab   84711

# %%
sns.catplot(data=tran_by_comp, x="Company", y="demand", kind="bar")

# %% [markdown]
# This barplot shows that the yellow cab have about thrice as high the transaction in the Pink Cab

# %%
#Average Profit by Company
#Checking Cab with most transactions during the time period
comp_by_profit = data.groupby('Company')['Profit'].mean().reset_index().sort_values(by='Profit', ascending = False)
comp_by_profit
# Out:
#       Company      Profit
# 1  Yellow Cab  160.259986
# 0    Pink Cab   62.652174

# %%
sns.catplot(data=comp_by_profit, x="Company", y="Profit", kind="bar")

# %% [markdown]
# The average profit for the Yellow cab is about 160 dollars  while that for yellow carb is about 63 dollars

# %%
sns.catplot(data=data, y="Payment_Mode", hue="Company", kind="count",
    palette="pastel", edgecolor=".6",)

# %% [markdown]
# The Yellow cab recorded more payment method both in cash and card

# %%
sns.catplot(data=data, x="Company", y="Age", hue="Gender", kind="violin", split=True,)

# %% [markdown]
# This shows the distribution of age is similar in both cab company, with the median age falling between 30-35 years. It also shows that Cabs are more frequently used by people aged 20 - 40 years.

# %%
data['Date of Travel'] = pd.to_datetime(data['Date of Travel'])
data['year'] = data['Date of Travel'].dt.year
data['month'] = data['Date of Travel'].dt.month

# %%
data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-08-01  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-06-01  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-02-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-07-01  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-03-01  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit  Customer ID Gender  Age  \
# 0         370.95       313.635  57.315        29290   Male   28
# 1         358.52       334.854  23.666        27703   Male   27
# 2         125.20        97.632  27.568        28712   Male   53
# 3         377.40       351.602  25.798        28020   Male   23
# 4         114.62        97.776  16.844        27182   Male   33
#
#    Income (USD/Month) Payment_Mode  year  month
# 0               10813         Card  2016      8
# 1                9237         Card  2016      6
# ...

# %%
data['demand'] = data.groupby(['month','year','Company'])['Transaction ID'].transform('count')

# %%
data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-08-01  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-06-01  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-02-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-07-01  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-03-01  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit  Customer ID Gender  Age  \
# 0         370.95       313.635  57.315        29290   Male   28
# 1         358.52       334.854  23.666        27703   Male   27
# 2         125.20        97.632  27.568        28712   Male   53
# 3         377.40       351.602  25.798        28020   Male   23
# 4         114.62        97.776  16.844        27182   Male   33
#
#    Income (USD/Month) Payment_Mode  year  month  demand
# 0               10813         Card  2016      8    2337
# ...

# %%
data_yellow = data[data['Company']=='Yellow Cab']
data_yellow
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 233           10000384     2016-02-01  Yellow Cab     ATLANTA GA
# 234           10000385     2016-09-01  Yellow Cab     ATLANTA GA
# 235           10000386     2016-03-01  Yellow Cab     ATLANTA GA
# 236           10000387     2016-06-01  Yellow Cab     ATLANTA GA
# 237           10000388     2016-07-01  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-08-01  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-04-01  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-05-01  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-05-01  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-02-01  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip    Profit  Customer ID  \
# 233            33.93        1341.17      464.1624  877.0076        27602
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=data_yellow, x="month", y="demand", hue="year")
plt.title("Monthly Yellow Cab demand from 2016 to 2018")
# Out:
# Text(0.5, 1.0, 'Monthly Yellow Cab demand from 2016 to 2018')

# %%
data_pink = data[data['Company']=='Pink Cab']

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=data_pink, x="month", y="demand", hue="year")
plt.title("Monthly Pink Cab demand from 2016 to 2018")
# Out:
# Text(0.5, 1.0, 'Monthly Pink Cab demand from 2016 to 2018')

# %%
#Transaction trend  by Year
yearly_demand = data.groupby(['year','Company'])['Transaction ID'].count().reset_index()
yearly_demand.rename(columns={'Transaction ID': 'count'}, inplace=True)
yearly_demand
# Out:
#    year     Company  count
# 0  2016    Pink Cab  25080
# 1  2016  Yellow Cab  82239
# 2  2017    Pink Cab  30321
# 3  2017  Yellow Cab  98189
# 4  2018    Pink Cab  29310
# 5  2018  Yellow Cab  94253

# %%
yearly_profit = data.groupby(['year','Company'])['Profit'].mean().reset_index()
yearly_profit.rename(columns={'Transaction ID': 'Avg Profit'}, inplace=True)
yearly_profit
# Out:
#    year     Company      Profit
# 0  2016    Pink Cab   68.321819
# 1  2016  Yellow Cab  169.347821
# 2  2017    Pink Cab   67.070839
# 3  2017  Yellow Cab  168.817057
# 4  2018    Pink Cab   53.229689
# 5  2018  Yellow Cab  143.416122

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=yearly_demand, x="year", y="count", hue="Company")
plt.title("Cab demand from 2016 to 2018")
# Out:
# Text(0.5, 1.0, 'Cab demand from 2016 to 2018')

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=data, x="year", y="Profit", hue="Company")

# %% [markdown]
# This shows there was a sharp decline in profit in both cabs from 2017 to 2018.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
d = data[data['Company']=='Pink Cab']
sns.lineplot(d['month'], d['Profit'], hue=d['year'])
plt.title("Monthly Pink Cab Profit from 2016 to 2018")
# Out:
# Text(0.5, 1.0, 'Monthly Pink Cab Profit from 2016 to 2018')

# %%
fig, ax = plt.subplots(figsize=(12, 6))
y = data[data['Company']=='Yellow Cab']
sns.lineplot(y['month'], y['Profit'], hue=y['year'])
plt.title("Monthly Yellow Cab Profit from 2016 to 2018")
# Out:
# Text(0.5, 1.0, 'Monthly Yellow Cab Profit from 2016 to 2018')

# %%
data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-08-01  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-06-01  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-02-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-07-01  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-03-01  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit  Customer ID Gender  Age  \
# 0         370.95       313.635  57.315        29290   Male   28
# 1         358.52       334.854  23.666        27703   Male   27
# 2         125.20        97.632  27.568        28712   Male   53
# 3         377.40       351.602  25.798        28020   Male   23
# 4         114.62        97.776  16.844        27182   Male   33
#
#    Income (USD/Month) Payment_Mode  year  month
# 0               10813         Card  2016      8
# 1                9237         Card  2016      6
# ...

# %%
transactions = data.groupby(['year','Company'])['Transaction ID'].count().reset_index().sort_values(by ='Transaction ID', ascending = False)
transactions
# Out:
#    year     Company  Transaction ID
# 3  2017  Yellow Cab           98189
# 5  2018  Yellow Cab           94253
# 1  2016  Yellow Cab           82239
# 2  2017    Pink Cab           30321
# 4  2018    Pink Cab           29310
# 0  2016    Pink Cab           25080

# %%
sns.catplot(data=transactions, x="year", y="Transaction ID", hue="Company", kind="bar")

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

sns.boxplot(d['year'], d['Profit'], ax=ax[0])
ax[0].set_title('Year-wise Box Plot\n(The Trend) for Pink Cab', fontsize = 20, loc='center', fontdict=dict(weight='bold'))


sns.boxplot(d['month'], d['Profit'], ax=ax[1])
ax[1].set_title('Month-wise Box Plot\n(The Seasonality) for Pink Cab', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
# Out:
# Text(0.5, 1.0, 'Month-wise Box Plot\n(The Seasonality) for Pink Cab')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

sns.boxplot(y['year'], y['Profit'], ax=ax[0])
ax[0].set_title('Year-wise Box Plot\n(The Trend) for Yellow Cab', fontsize = 20, loc='center', fontdict=dict(weight='bold'))


sns.boxplot(y['month'], y['Profit'], ax=ax[1])
ax[1].set_title('Month-wise Box Plot\n(The Seasonality) for Yellow Cab', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
# Out:
# Text(0.5, 1.0, 'Month-wise Box Plot\n(The Seasonality) for Yellow Cab')

# %%
sns.catplot(data=data, y="City", hue="Company", kind="count", palette="pastel", edgecolor=".6")
plt.xlabel("count")
plt.ylabel("City")
plt.title("Car demand by City colored by Company")
# Out:
# Text(0.5, 1.0, 'Car demand by City colored by Company')

# %%
d['Customer ID'].duplicated().count()
# Out:
# 84711

# %%
y['Customer ID'].duplicated().count()
# Out:
# 274681

# %%
data_pink = d
data_yellow = y

# %%
data_pink.describe().transpose()
# Out:
#                       count          mean            std          min  \
# Transaction ID      84711.0  1.022394e+07  126178.205348  10000011.00
# KM Travelled        84711.0  2.255992e+01      12.231092         1.90
# Price Charged       84711.0  3.108009e+02     181.995661        15.60
# Cost of Trip        84711.0  2.481487e+02     135.403345        19.00
# Profit              84711.0  6.265217e+01      77.590378      -220.06
# Customer ID         84711.0  1.842258e+04   18084.830799         1.00
# Age                 84711.0  3.532241e+01      12.644780        18.00
# Income (USD/Month)  84711.0  1.505905e+04    7991.077762      2000.00
# year                84711.0  2.017050e+03       0.799737      2016.00
# month               84711.0  7.347369e+00       3.365964         1.00
#
#                              25%          50%           75%          max
# Transaction ID      1.011014e+07  10225904.00  1.033642e+07  10437615.00
# ...

# %%
#Customer Retention for Pink Cab
n_demand = data_pink[data_pink['year']==2016].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand > 1) / data_pink['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 16.92% of customers ordered more than once.

# %%
n_demand = data_pink[data_pink['year']==2017].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand > 1) / data_pink['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 21.75% of customers ordered more than once.

# %%
n_demand = data_pink[data_pink['year']==2018].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand > 1) / data_pink['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 20.66% of customers ordered more than once.

# %%
ax = sns.distplot(n_demand, kde=False, hist=True)
ax.set(title='Distribution of demand per customer for Pink Cab',
       xlabel='number of orders', 
       ylabel='number of customers');

# %%
#Customer Retention of Yellow Carb
n_demand_y = data_yellow[data_yellow['year']== 2016].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand_y > 1) / data_yellow['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 38.90% of customers ordered more than once.

# %%
n_demand_y = data_yellow[data_yellow['year']== 2017].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand_y > 1) / data_yellow['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 42.54% of customers ordered more than once.

# %%
n_demand_y = data_yellow[data_yellow['year']== 2018].groupby(['Customer ID'])['Transaction ID'].nunique()
mult_demand_perc = np.sum(n_demand_y > 1) / data_yellow['Customer ID'].nunique()
print(f'{100 * mult_demand_perc:.2f}% of customers ordered more than once.')
# Out:
# 41.81% of customers ordered more than once.

# %%
#Creating a Datafrome for Customer retention over 3 years for each company
cust_retention = [['yellow cab','2016', 39], ['yellow cab','2017', 43], ['yellow cab','2018', 42],
                 ['pink cab','2016',17],['pink cab','2017', 22],['pink cab','2018', 21]]
cust_retention = pd.DataFrame(cust_retention, columns=['Company', 'Year', '% of multiple orders'])
cust_retention
# Out:
#       Company  Year  % of multiple orders
# 0  yellow cab  2016                    39
# 1  yellow cab  2017                    43
# 2  yellow cab  2018                    42
# 3    pink cab  2016                    17
# 4    pink cab  2017                    22
# 5    pink cab  2018                    21

# %%
sns.catplot(data=cust_retention, x="Year", y="% of multiple orders", hue="Company", kind="bar")

# %%
ax = sns.distplot(n_demand_y, kde=False, hist=True)
ax.set(title='Distribution of demand per customer for Yellow Cab',
       xlabel='number of orders', 
       ylabel='number of customers');

# %%
sns.lmplot( x="KM Travelled", y="Profit", data=data_yellow, fit_reg=True)

# %%
sns.lmplot( x="KM Travelled", y="Profit", data=data_pink, fit_reg=True)

# %%
sns.lmplot( x="KM Travelled", y="Price Charged", data=data_pink, fit_reg=False, hue='City')
plt.title("Price Charged Per Km for Pink Cab in each city ")
# Out:
# Text(0.5, 1.0, 'Price Charged Per Km for Pink Cab in each city ')

# %%
sns.lmplot( x="KM Travelled", y="Price Charged", data=data_yellow, fit_reg=False, hue='City')
plt.title("Price Charged Per Km for Yellow Cab in each city ")
# Out:
# Text(0.5, 1.0, 'Price Charged Per Km for Yellow Cab in each city ')

# %%
yearly_demand_yellow = data_yellow.groupby(['year'])['Transaction ID'].count().reset_index()
yearly_demand_yellow
# Out:
#    year  Transaction ID
# 0  2016           82239
# 1  2017           98189
# 2  2018           94253

# %%
yearly_demand_yellow['Percentage_change'] = yearly_demand_yellow['Transaction ID'].pct_change()

# %%
yearly_demand_yellow
# Out:
#    year  Transaction ID  Percentage_change
# 0  2016           82239                NaN
# 1  2017           98189           0.193947
# 2  2018           94253          -0.040086

# %%
yearly_demand_pink = data_pink.groupby(['year'])['Transaction ID'].count().reset_index()
yearly_demand_pink
# Out:
#    year  Transaction ID
# 0  2016           25080
# 1  2017           30321
# 2  2018           29310

# %%
yearly_demand_pink['Percentage_change'] = yearly_demand_pink['Transaction ID'].pct_change()

# %%
yearly_demand_pink
# Out:
#    year  Transaction ID  Percentage_change
# 0  2016           25080                NaN
# 1  2017           30321           0.208971
# 2  2018           29310          -0.033343

# %%
yearly_profit_yellow = data_yellow.groupby(['year'])['Profit'].sum().reset_index()
yearly_profit_yellow
# Out:
#    year        Profit
# 0  2016  1.392700e+07
# 1  2017  1.657598e+07
# 2  2018  1.351740e+07

# %%
yearly_profit_pink = data_pink.groupby(['year'])['Profit'].sum().reset_index()
yearly_profit_pink
# Out:
#    year       Profit
# 0  2016  1713511.224
# 1  2017  2033654.908
# 2  2018  1560162.189
